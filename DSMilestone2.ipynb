# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
nasa = pd.read_csv("NASAexoplanet.csv")
nasa
# Out:
#                       name  distance  stellar_magnitude  planet_type  \
# 0     11 Comae Berenices b     304.0            4.72307    Gas Giant
# 1       11 Ursae Minoris b     409.0            5.01300    Gas Giant
# 2          14 Andromedae b     246.0            5.23133    Gas Giant
# 3            14 Herculis b      58.0            6.61935    Gas Giant
# 4             16 Cygni B b      69.0            6.21500    Gas Giant
# ...                    ...       ...                ...          ...
# 5245                XO-7 b     764.0           10.52100    Gas Giant
# 5246              YSES 2 b     357.0           10.88500    Gas Giant
# 5247             YZ Ceti b      12.0           12.07400  Terrestrial
# 5248             YZ Ceti c      12.0           12.07400  Super Earth
# 5249             YZ Ceti d      12.0           12.07400  Super Earth
#
#       discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# 0               2007         19.40000  Jupiter              1.080    Jupiter
# 1               2009         14.74000  Jupiter              1.090    Jupiter
# 2               2008          4.80000  Jupiter              1.150    Jupiter
# 3               2002          8.13881  Jupiter              1.120    Jupiter
# 4               1996          1.78000  Jupiter              1.200    Jupiter
# ...              ...              ...      ...                ...        ...
# 5245            2019          0.70900  Jupiter              1.373    Jupiter
# 5246            2021          6.30000  Jupiter              1.140    Jupiter
# 5247            2017          0.70000    Earth              0.913      Earth
# 5248            2017          1.14000    Earth              1.050      Earth
# 5249            2017          1.09000    Earth              1.030      Earth
#
#       orbital_radius  orbital_period  eccentricity detection_method
# 0           1.290000        0.892539          0.23  Radial Velocity
# 1           1.530000        1.400000          0.08  Radial Velocity
# 2           0.830000        0.508693          0.00  Radial Velocity
# 3           2.773069        4.800000          0.37  Radial Velocity
# 4           1.660000        2.200000          0.68  Radial Velocity
# ...              ...             ...           ...              ...
# 5245        0.044210        0.007940          0.04          Transit
# 5246      115.000000     1176.500000          0.00   Direct Imaging
# 5247        0.016340        0.005476          0.06  Radial Velocity
# 5248        0.021560        0.008487          0.00  Radial Velocity
# 5249        0.028510        0.012868          0.07  Radial Velocity
#
# [5250 rows x 13 columns]

# %%
#Assessing the data
#structure/shape
#scope and completeness
#temporality
#faithfulness
nasa.describe()
# Out:
#            distance  stellar_magnitude  discovery_year  mass_multiplier  \
# count   5233.000000        5089.000000     5250.000000      5227.000000
# mean    2167.168737          12.683738     2015.732190         6.434812
# std     3245.522087           3.107571        4.307336        12.972727
# min        4.000000           0.872000     1992.000000         0.020000
# 25%      389.000000          10.939000     2014.000000         1.804000
# 50%     1371.000000          13.543000     2016.000000         4.170140
# 75%     2779.000000          15.021000     2018.000000         8.000000
# max    27727.000000          44.610000     2023.000000       752.000000
#
#        radius_multiplier  orbital_radius  orbital_period  eccentricity
# count        5233.000000     4961.000000    5.250000e+03   5250.000000
# mean            1.015121        6.962942    4.791509e+02      0.063568
# std             0.603479      138.673600    1.680445e+04      0.141424
# min             0.200000        0.004400    2.737851e-04     -0.520000
# 25%             0.325000        0.053000    1.259411e-02      0.000000
# 50%             1.120000        0.102800    3.449692e-02      0.000000
# 75%             1.410000        0.286000    1.442163e-01      0.060000
# max             6.900000     7506.000000    1.101370e+06      0.950000

# %%
nasa.describe(include = ["O"])
#missing data
#distance - 17
#stellar magnitude - 161
#mass multiplier - 23
#radius multiplier - 17
#orbital radius - 289
#mass_wrt - 23
#radius_wrt - 17
# Out:
#                         name   planet_type mass_wrt radius_wrt  \
# count                   5250          5250     5227       5233
# unique                  5250             5        2          2
# top     11 Comae Berenices b  Neptune-like    Earth    Jupiter
# freq                       1          1825     3586       3310
#
#        detection_method
# count              5250
# unique               11
# top             Transit
# freq               3945

# %%
nasa.isna().any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5245    False
# 5246    False
# 5247    False
# 5248    False
# 5249    False
# Length: 5250, dtype: bool

# %%
#Cleaning data
missing_data = nasa["orbital_radius"].isna()
#missing_data = nasa_exo["distance"].isna()
nasa2 = nasa[~missing_data]
nasa2
# Out:
#                       name  distance  stellar_magnitude  planet_type  \
# 0     11 Comae Berenices b     304.0            4.72307    Gas Giant
# 1       11 Ursae Minoris b     409.0            5.01300    Gas Giant
# 2          14 Andromedae b     246.0            5.23133    Gas Giant
# 3            14 Herculis b      58.0            6.61935    Gas Giant
# 4             16 Cygni B b      69.0            6.21500    Gas Giant
# ...                    ...       ...                ...          ...
# 5245                XO-7 b     764.0           10.52100    Gas Giant
# 5246              YSES 2 b     357.0           10.88500    Gas Giant
# 5247             YZ Ceti b      12.0           12.07400  Terrestrial
# 5248             YZ Ceti c      12.0           12.07400  Super Earth
# 5249             YZ Ceti d      12.0           12.07400  Super Earth
#
#       discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# 0               2007         19.40000  Jupiter              1.080    Jupiter
# 1               2009         14.74000  Jupiter              1.090    Jupiter
# 2               2008          4.80000  Jupiter              1.150    Jupiter
# 3               2002          8.13881  Jupiter              1.120    Jupiter
# 4               1996          1.78000  Jupiter              1.200    Jupiter
# ...              ...              ...      ...                ...        ...
# 5245            2019          0.70900  Jupiter              1.373    Jupiter
# 5246            2021          6.30000  Jupiter              1.140    Jupiter
# 5247            2017          0.70000    Earth              0.913      Earth
# 5248            2017          1.14000    Earth              1.050      Earth
# 5249            2017          1.09000    Earth              1.030      Earth
#
#       orbital_radius  orbital_period  eccentricity detection_method
# 0           1.290000        0.892539          0.23  Radial Velocity
# 1           1.530000        1.400000          0.08  Radial Velocity
# 2           0.830000        0.508693          0.00  Radial Velocity
# 3           2.773069        4.800000          0.37  Radial Velocity
# 4           1.660000        2.200000          0.68  Radial Velocity
# ...              ...             ...           ...              ...
# 5245        0.044210        0.007940          0.04          Transit
# 5246      115.000000     1176.500000          0.00   Direct Imaging
# 5247        0.016340        0.005476          0.06  Radial Velocity
# 5248        0.021560        0.008487          0.00  Radial Velocity
# 5249        0.028510        0.012868          0.07  Radial Velocity
#
# [4961 rows x 13 columns]

# %%
missing_data = nasa2["distance"].isna()
nasa3 = nasa2[~missing_data]
nasa3
# Out:
#                       name  distance  stellar_magnitude  planet_type  \
# 0     11 Comae Berenices b     304.0            4.72307    Gas Giant
# 1       11 Ursae Minoris b     409.0            5.01300    Gas Giant
# 2          14 Andromedae b     246.0            5.23133    Gas Giant
# 3            14 Herculis b      58.0            6.61935    Gas Giant
# 4             16 Cygni B b      69.0            6.21500    Gas Giant
# ...                    ...       ...                ...          ...
# 5245                XO-7 b     764.0           10.52100    Gas Giant
# 5246              YSES 2 b     357.0           10.88500    Gas Giant
# 5247             YZ Ceti b      12.0           12.07400  Terrestrial
# 5248             YZ Ceti c      12.0           12.07400  Super Earth
# 5249             YZ Ceti d      12.0           12.07400  Super Earth
#
#       discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# 0               2007         19.40000  Jupiter              1.080    Jupiter
# 1               2009         14.74000  Jupiter              1.090    Jupiter
# 2               2008          4.80000  Jupiter              1.150    Jupiter
# 3               2002          8.13881  Jupiter              1.120    Jupiter
# 4               1996          1.78000  Jupiter              1.200    Jupiter
# ...              ...              ...      ...                ...        ...
# 5245            2019          0.70900  Jupiter              1.373    Jupiter
# 5246            2021          6.30000  Jupiter              1.140    Jupiter
# 5247            2017          0.70000    Earth              0.913      Earth
# 5248            2017          1.14000    Earth              1.050      Earth
# 5249            2017          1.09000    Earth              1.030      Earth
#
#       orbital_radius  orbital_period  eccentricity detection_method
# 0           1.290000        0.892539          0.23  Radial Velocity
# 1           1.530000        1.400000          0.08  Radial Velocity
# 2           0.830000        0.508693          0.00  Radial Velocity
# 3           2.773069        4.800000          0.37  Radial Velocity
# 4           1.660000        2.200000          0.68  Radial Velocity
# ...              ...             ...           ...              ...
# 5245        0.044210        0.007940          0.04          Transit
# 5246      115.000000     1176.500000          0.00   Direct Imaging
# 5247        0.016340        0.005476          0.06  Radial Velocity
# 5248        0.021560        0.008487          0.00  Radial Velocity
# 5249        0.028510        0.012868          0.07  Radial Velocity
#
# [4944 rows x 13 columns]

# %%
missing_data = nasa["stellar_magnitude"].isna()
nasa4 = nasa3[~missing_data]
nasa4
# Out:
# /tmp/ipykernel_687/1065416320.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nasa4 = nasa3[~missing_data]
#                       name  distance  stellar_magnitude  planet_type  \
# 0     11 Comae Berenices b     304.0            4.72307    Gas Giant
# 1       11 Ursae Minoris b     409.0            5.01300    Gas Giant
# 2          14 Andromedae b     246.0            5.23133    Gas Giant
# 3            14 Herculis b      58.0            6.61935    Gas Giant
# 4             16 Cygni B b      69.0            6.21500    Gas Giant
# ...                    ...       ...                ...          ...
# 5245                XO-7 b     764.0           10.52100    Gas Giant
# 5246              YSES 2 b     357.0           10.88500    Gas Giant
# 5247             YZ Ceti b      12.0           12.07400  Terrestrial
# 5248             YZ Ceti c      12.0           12.07400  Super Earth
# 5249             YZ Ceti d      12.0           12.07400  Super Earth
#
#       discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# 0               2007         19.40000  Jupiter              1.080    Jupiter
# 1               2009         14.74000  Jupiter              1.090    Jupiter
# 2               2008          4.80000  Jupiter              1.150    Jupiter
# 3               2002          8.13881  Jupiter              1.120    Jupiter
# 4               1996          1.78000  Jupiter              1.200    Jupiter
# ...              ...              ...      ...                ...        ...
# 5245            2019          0.70900  Jupiter              1.373    Jupiter
# 5246            2021          6.30000  Jupiter              1.140    Jupiter
# 5247            2017          0.70000    Earth              0.913      Earth
# 5248            2017          1.14000    Earth              1.050      Earth
# 5249            2017          1.09000    Earth              1.030      Earth
#
#       orbital_radius  orbital_period  eccentricity detection_method
# 0           1.290000        0.892539          0.23  Radial Velocity
# 1           1.530000        1.400000          0.08  Radial Velocity
# 2           0.830000        0.508693          0.00  Radial Velocity
# 3           2.773069        4.800000          0.37  Radial Velocity
# 4           1.660000        2.200000          0.68  Radial Velocity
# ...              ...             ...           ...              ...
# 5245        0.044210        0.007940          0.04          Transit
# 5246      115.000000     1176.500000          0.00   Direct Imaging
# 5247        0.016340        0.005476          0.06  Radial Velocity
# 5248        0.021560        0.008487          0.00  Radial Velocity
# 5249        0.028510        0.012868          0.07  Radial Velocity
#
# [4792 rows x 13 columns]

# %%
missing_data = nasa["mass_multiplier"].isna()
nasa5 = nasa4[~missing_data]
nasa5
# Out:
# /tmp/ipykernel_687/2764954486.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nasa5 = nasa4[~missing_data]
#                       name  distance  stellar_magnitude  planet_type  \
# 0     11 Comae Berenices b     304.0            4.72307    Gas Giant
# 1       11 Ursae Minoris b     409.0            5.01300    Gas Giant
# 2          14 Andromedae b     246.0            5.23133    Gas Giant
# 3            14 Herculis b      58.0            6.61935    Gas Giant
# 4             16 Cygni B b      69.0            6.21500    Gas Giant
# ...                    ...       ...                ...          ...
# 5245                XO-7 b     764.0           10.52100    Gas Giant
# 5246              YSES 2 b     357.0           10.88500    Gas Giant
# 5247             YZ Ceti b      12.0           12.07400  Terrestrial
# 5248             YZ Ceti c      12.0           12.07400  Super Earth
# 5249             YZ Ceti d      12.0           12.07400  Super Earth
#
#       discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# 0               2007         19.40000  Jupiter              1.080    Jupiter
# 1               2009         14.74000  Jupiter              1.090    Jupiter
# 2               2008          4.80000  Jupiter              1.150    Jupiter
# 3               2002          8.13881  Jupiter              1.120    Jupiter
# 4               1996          1.78000  Jupiter              1.200    Jupiter
# ...              ...              ...      ...                ...        ...
# 5245            2019          0.70900  Jupiter              1.373    Jupiter
# 5246            2021          6.30000  Jupiter              1.140    Jupiter
# 5247            2017          0.70000    Earth              0.913      Earth
# 5248            2017          1.14000    Earth              1.050      Earth
# 5249            2017          1.09000    Earth              1.030      Earth
#
#       orbital_radius  orbital_period  eccentricity detection_method
# 0           1.290000        0.892539          0.23  Radial Velocity
# 1           1.530000        1.400000          0.08  Radial Velocity
# 2           0.830000        0.508693          0.00  Radial Velocity
# 3           2.773069        4.800000          0.37  Radial Velocity
# 4           1.660000        2.200000          0.68  Radial Velocity
# ...              ...             ...           ...              ...
# 5245        0.044210        0.007940          0.04          Transit
# 5246      115.000000     1176.500000          0.00   Direct Imaging
# 5247        0.016340        0.005476          0.06  Radial Velocity
# 5248        0.021560        0.008487          0.00  Radial Velocity
# 5249        0.028510        0.012868          0.07  Radial Velocity
#
# [4774 rows x 13 columns]

# %%
missing_data = nasa["radius_multiplier"].isna()
nasa6 = nasa5[~missing_data]
nasa5
# Out:
# /tmp/ipykernel_687/350766048.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nasa6 = nasa5[~missing_data]
#                       name  distance  stellar_magnitude  planet_type  \
# 0     11 Comae Berenices b     304.0            4.72307    Gas Giant
# 1       11 Ursae Minoris b     409.0            5.01300    Gas Giant
# 2          14 Andromedae b     246.0            5.23133    Gas Giant
# 3            14 Herculis b      58.0            6.61935    Gas Giant
# 4             16 Cygni B b      69.0            6.21500    Gas Giant
# ...                    ...       ...                ...          ...
# 5245                XO-7 b     764.0           10.52100    Gas Giant
# 5246              YSES 2 b     357.0           10.88500    Gas Giant
# 5247             YZ Ceti b      12.0           12.07400  Terrestrial
# 5248             YZ Ceti c      12.0           12.07400  Super Earth
# 5249             YZ Ceti d      12.0           12.07400  Super Earth
#
#       discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# 0               2007         19.40000  Jupiter              1.080    Jupiter
# 1               2009         14.74000  Jupiter              1.090    Jupiter
# 2               2008          4.80000  Jupiter              1.150    Jupiter
# 3               2002          8.13881  Jupiter              1.120    Jupiter
# 4               1996          1.78000  Jupiter              1.200    Jupiter
# ...              ...              ...      ...                ...        ...
# 5245            2019          0.70900  Jupiter              1.373    Jupiter
# 5246            2021          6.30000  Jupiter              1.140    Jupiter
# 5247            2017          0.70000    Earth              0.913      Earth
# 5248            2017          1.14000    Earth              1.050      Earth
# 5249            2017          1.09000    Earth              1.030      Earth
#
#       orbital_radius  orbital_period  eccentricity detection_method
# 0           1.290000        0.892539          0.23  Radial Velocity
# 1           1.530000        1.400000          0.08  Radial Velocity
# 2           0.830000        0.508693          0.00  Radial Velocity
# 3           2.773069        4.800000          0.37  Radial Velocity
# 4           1.660000        2.200000          0.68  Radial Velocity
# ...              ...             ...           ...              ...
# 5245        0.044210        0.007940          0.04          Transit
# 5246      115.000000     1176.500000          0.00   Direct Imaging
# 5247        0.016340        0.005476          0.06  Radial Velocity
# 5248        0.021560        0.008487          0.00  Radial Velocity
# 5249        0.028510        0.012868          0.07  Radial Velocity
#
# [4774 rows x 13 columns]

# %%
missing_data = nasa["mass_wrt"].isna()
nasa7 = nasa6[~missing_data]
nasa7
# Out:
# /tmp/ipykernel_687/2649695994.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nasa7 = nasa6[~missing_data]
#                       name  distance  stellar_magnitude  planet_type  \
# 0     11 Comae Berenices b     304.0            4.72307    Gas Giant
# 1       11 Ursae Minoris b     409.0            5.01300    Gas Giant
# 2          14 Andromedae b     246.0            5.23133    Gas Giant
# 3            14 Herculis b      58.0            6.61935    Gas Giant
# 4             16 Cygni B b      69.0            6.21500    Gas Giant
# ...                    ...       ...                ...          ...
# 5245                XO-7 b     764.0           10.52100    Gas Giant
# 5246              YSES 2 b     357.0           10.88500    Gas Giant
# 5247             YZ Ceti b      12.0           12.07400  Terrestrial
# 5248             YZ Ceti c      12.0           12.07400  Super Earth
# 5249             YZ Ceti d      12.0           12.07400  Super Earth
#
#       discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# 0               2007         19.40000  Jupiter              1.080    Jupiter
# 1               2009         14.74000  Jupiter              1.090    Jupiter
# 2               2008          4.80000  Jupiter              1.150    Jupiter
# 3               2002          8.13881  Jupiter              1.120    Jupiter
# 4               1996          1.78000  Jupiter              1.200    Jupiter
# ...              ...              ...      ...                ...        ...
# 5245            2019          0.70900  Jupiter              1.373    Jupiter
# 5246            2021          6.30000  Jupiter              1.140    Jupiter
# 5247            2017          0.70000    Earth              0.913      Earth
# 5248            2017          1.14000    Earth              1.050      Earth
# 5249            2017          1.09000    Earth              1.030      Earth
#
#       orbital_radius  orbital_period  eccentricity detection_method
# 0           1.290000        0.892539          0.23  Radial Velocity
# 1           1.530000        1.400000          0.08  Radial Velocity
# 2           0.830000        0.508693          0.00  Radial Velocity
# 3           2.773069        4.800000          0.37  Radial Velocity
# 4           1.660000        2.200000          0.68  Radial Velocity
# ...              ...             ...           ...              ...
# 5245        0.044210        0.007940          0.04          Transit
# 5246      115.000000     1176.500000          0.00   Direct Imaging
# 5247        0.016340        0.005476          0.06  Radial Velocity
# 5248        0.021560        0.008487          0.00  Radial Velocity
# 5249        0.028510        0.012868          0.07  Radial Velocity
#
# [4765 rows x 13 columns]

# %%
missing_data = nasa["radius_wrt"].isna()
nasa_exo = nasa7[~missing_data]
nasa_exo
# Out:
# /tmp/ipykernel_687/2099458126.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nasa_exo = nasa7[~missing_data]
#                       name  distance  stellar_magnitude  planet_type  \
# 0     11 Comae Berenices b     304.0            4.72307    Gas Giant
# 1       11 Ursae Minoris b     409.0            5.01300    Gas Giant
# 2          14 Andromedae b     246.0            5.23133    Gas Giant
# 3            14 Herculis b      58.0            6.61935    Gas Giant
# 4             16 Cygni B b      69.0            6.21500    Gas Giant
# ...                    ...       ...                ...          ...
# 5245                XO-7 b     764.0           10.52100    Gas Giant
# 5246              YSES 2 b     357.0           10.88500    Gas Giant
# 5247             YZ Ceti b      12.0           12.07400  Terrestrial
# 5248             YZ Ceti c      12.0           12.07400  Super Earth
# 5249             YZ Ceti d      12.0           12.07400  Super Earth
#
#       discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# 0               2007         19.40000  Jupiter              1.080    Jupiter
# 1               2009         14.74000  Jupiter              1.090    Jupiter
# 2               2008          4.80000  Jupiter              1.150    Jupiter
# 3               2002          8.13881  Jupiter              1.120    Jupiter
# 4               1996          1.78000  Jupiter              1.200    Jupiter
# ...              ...              ...      ...                ...        ...
# 5245            2019          0.70900  Jupiter              1.373    Jupiter
# 5246            2021          6.30000  Jupiter              1.140    Jupiter
# 5247            2017          0.70000    Earth              0.913      Earth
# 5248            2017          1.14000    Earth              1.050      Earth
# 5249            2017          1.09000    Earth              1.030      Earth
#
#       orbital_radius  orbital_period  eccentricity detection_method
# 0           1.290000        0.892539          0.23  Radial Velocity
# 1           1.530000        1.400000          0.08  Radial Velocity
# 2           0.830000        0.508693          0.00  Radial Velocity
# 3           2.773069        4.800000          0.37  Radial Velocity
# 4           1.660000        2.200000          0.68  Radial Velocity
# ...              ...             ...           ...              ...
# 5245        0.044210        0.007940          0.04          Transit
# 5246      115.000000     1176.500000          0.00   Direct Imaging
# 5247        0.016340        0.005476          0.06  Radial Velocity
# 5248        0.021560        0.008487          0.00  Radial Velocity
# 5249        0.028510        0.012868          0.07  Radial Velocity
#
# [4765 rows x 13 columns]

# %%
#renaming columns
new_columns = ["name", "distance","stellar magnitude", "planet type", "year", "mass x", "mass ssc", "radius x", "radius ssc", "oribital radius", "orbital period", "eccentricity", "detection method"]
nasa_exo.columns = new_columns
nasa_exo
# Out:
#                       name  distance  stellar magnitude  planet type  year  \
# 0     11 Comae Berenices b     304.0            4.72307    Gas Giant  2007
# 1       11 Ursae Minoris b     409.0            5.01300    Gas Giant  2009
# 2          14 Andromedae b     246.0            5.23133    Gas Giant  2008
# 3            14 Herculis b      58.0            6.61935    Gas Giant  2002
# 4             16 Cygni B b      69.0            6.21500    Gas Giant  1996
# ...                    ...       ...                ...          ...   ...
# 5245                XO-7 b     764.0           10.52100    Gas Giant  2019
# 5246              YSES 2 b     357.0           10.88500    Gas Giant  2021
# 5247             YZ Ceti b      12.0           12.07400  Terrestrial  2017
# 5248             YZ Ceti c      12.0           12.07400  Super Earth  2017
# 5249             YZ Ceti d      12.0           12.07400  Super Earth  2017
#
#         mass x mass ssc  radius x radius ssc  oribital radius  orbital period  \
# 0     19.40000  Jupiter     1.080    Jupiter         1.290000        0.892539
# 1     14.74000  Jupiter     1.090    Jupiter         1.530000        1.400000
# 2      4.80000  Jupiter     1.150    Jupiter         0.830000        0.508693
# 3      8.13881  Jupiter     1.120    Jupiter         2.773069        4.800000
# 4      1.78000  Jupiter     1.200    Jupiter         1.660000        2.200000
# ...        ...      ...       ...        ...              ...             ...
# 5245   0.70900  Jupiter     1.373    Jupiter         0.044210        0.007940
# 5246   6.30000  Jupiter     1.140    Jupiter       115.000000     1176.500000
# 5247   0.70000    Earth     0.913      Earth         0.016340        0.005476
# 5248   1.14000    Earth     1.050      Earth         0.021560        0.008487
# 5249   1.09000    Earth     1.030      Earth         0.028510        0.012868
#
#       eccentricity detection method
# 0             0.23  Radial Velocity
# 1             0.08  Radial Velocity
# 2             0.00  Radial Velocity
# 3             0.37  Radial Velocity
# 4             0.68  Radial Velocity
# ...            ...              ...
# 5245          0.04          Transit
# 5246          0.00   Direct Imaging
# 5247          0.06  Radial Velocity
# 5248          0.00  Radial Velocity
# 5249          0.07  Radial Velocity
#
# [4765 rows x 13 columns]

# %%
dup_filter = nasa_exo.duplicated()
nasa_exo[dup_filter]
#no duplicate rows
# Out:
# Empty DataFrame
# Columns: [name, distance, stellar magnitude, planet type, year, mass x, mass ssc, radius x, radius ssc, oribital radius, orbital period, eccentricity, detection method]
# Index: []

# %%
nasa_exo.dtypes
# Out:
# name                  object
# distance             float64
# stellar magnitude    float64
# planet type           object
# year                   int64
# mass x               float64
# mass ssc              object
# radius x             float64
# radius ssc            object
# oribital radius      float64
# orbital period       float64
# eccentricity         float64
# detection method      object
# dtype: object

# %%
nasa_exo["distance"] = nasa_exo["distance"].astype(int) #converting distance column to int
nasa_exo
# Out:
#                       name  distance  stellar magnitude  planet type  year  \
# 0     11 Comae Berenices b       304            4.72307    Gas Giant  2007
# 1       11 Ursae Minoris b       409            5.01300    Gas Giant  2009
# 2          14 Andromedae b       246            5.23133    Gas Giant  2008
# 3            14 Herculis b        58            6.61935    Gas Giant  2002
# 4             16 Cygni B b        69            6.21500    Gas Giant  1996
# ...                    ...       ...                ...          ...   ...
# 5245                XO-7 b       764           10.52100    Gas Giant  2019
# 5246              YSES 2 b       357           10.88500    Gas Giant  2021
# 5247             YZ Ceti b        12           12.07400  Terrestrial  2017
# 5248             YZ Ceti c        12           12.07400  Super Earth  2017
# 5249             YZ Ceti d        12           12.07400  Super Earth  2017
#
#         mass x mass ssc  radius x radius ssc  oribital radius  orbital period  \
# 0     19.40000  Jupiter     1.080    Jupiter         1.290000        0.892539
# 1     14.74000  Jupiter     1.090    Jupiter         1.530000        1.400000
# 2      4.80000  Jupiter     1.150    Jupiter         0.830000        0.508693
# 3      8.13881  Jupiter     1.120    Jupiter         2.773069        4.800000
# 4      1.78000  Jupiter     1.200    Jupiter         1.660000        2.200000
# ...        ...      ...       ...        ...              ...             ...
# 5245   0.70900  Jupiter     1.373    Jupiter         0.044210        0.007940
# 5246   6.30000  Jupiter     1.140    Jupiter       115.000000     1176.500000
# 5247   0.70000    Earth     0.913      Earth         0.016340        0.005476
# 5248   1.14000    Earth     1.050      Earth         0.021560        0.008487
# 5249   1.09000    Earth     1.030      Earth         0.028510        0.012868
#
#       eccentricity detection method
# 0             0.23  Radial Velocity
# 1             0.08  Radial Velocity
# 2             0.00  Radial Velocity
# 3             0.37  Radial Velocity
# 4             0.68  Radial Velocity
# ...            ...              ...
# 5245          0.04          Transit
# 5246          0.00   Direct Imaging
# 5247          0.06  Radial Velocity
# 5248          0.00  Radial Velocity
# 5249          0.07  Radial Velocity
#
# [4765 rows x 13 columns]

# %%
#Single variable distribution plots
nasa_exo["year"].hist(bins = 30)
plt.title("Exoplanets Discovery Throughout the Years")
plt.xlabel("Year")
plt.ylabel("Number of Exoplanets")
# Out:
# Text(0, 0.5, 'Number of Exoplanets')

# %%
nasa_exo["distance"].hist(bins = 25)
plt.title("Exoplanets Distance from Earth")
plt.xlabel("Distance (light year)")
plt.ylabel("Number of Exoplanets")
# Out:
# Text(0, 0.5, 'Number of Exoplanets')

# %%
type_counts = nasa_exo["planet type"].value_counts()
type_counts.plot(kind = "bar")
plt.title("Types of Planets")
plt.xlabel("Type")
plt.ylabel("# of Exoplanets")
# Out:
# Text(0, 0.5, '# of Exoplanets')

# %%
comparison_count= nasa_exo["radius ssc"].value_counts()
comparison_count.plot(kind = "bar")
plt.title("Compared Planets By Size")
plt.xlabel("Planet")
plt.ylabel("# of Exoplanets")
# Out:
# Text(0, 0.5, '# of Exoplanets')

# %%
#multiple variable plots

# %%
sns.relplot(x = "year", y = "stellar magnitude", kind = "line", ci = None, data = nasa_exo)
plt.title("Brightness of Discovered Exoplanets Throughout the Years")
# Out:
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.0, 'Brightness of Discovered Exoplanets Throughout the Years')

# %%
sns.relplot(x = "year", y = "distance", kind = "line", ci = None, data = nasa_exo)
plt.title("Distance of Discovered Exoplanets Throughout the Years")
# Out:
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.0, 'Distance of Discovered Exoplanets Throughout the Years')

# %%
sns.relplot(x = "distance", y = "stellar magnitude", kind = "line", ci = None, data = nasa_exo)
#plt.title("Brightness of Discovered Exoplanets Throughout the Years")
# Out:
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x = "year", y = "stellar magnitude", hue = "detection method", data = nasa_exo)
# Out:
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Project 2
#Machine Learning Models
nasa_exo
# Out:
#                       name  distance  stellar magnitude  planet type  year  \
# 0     11 Comae Berenices b       304            4.72307    Gas Giant  2007
# 1       11 Ursae Minoris b       409            5.01300    Gas Giant  2009
# 2          14 Andromedae b       246            5.23133    Gas Giant  2008
# 3            14 Herculis b        58            6.61935    Gas Giant  2002
# 4             16 Cygni B b        69            6.21500    Gas Giant  1996
# ...                    ...       ...                ...          ...   ...
# 5245                XO-7 b       764           10.52100    Gas Giant  2019
# 5246              YSES 2 b       357           10.88500    Gas Giant  2021
# 5247             YZ Ceti b        12           12.07400  Terrestrial  2017
# 5248             YZ Ceti c        12           12.07400  Super Earth  2017
# 5249             YZ Ceti d        12           12.07400  Super Earth  2017
#
#         mass x mass ssc  radius x radius ssc  oribital radius  orbital period  \
# 0     19.40000  Jupiter     1.080    Jupiter         1.290000        0.892539
# 1     14.74000  Jupiter     1.090    Jupiter         1.530000        1.400000
# 2      4.80000  Jupiter     1.150    Jupiter         0.830000        0.508693
# 3      8.13881  Jupiter     1.120    Jupiter         2.773069        4.800000
# 4      1.78000  Jupiter     1.200    Jupiter         1.660000        2.200000
# ...        ...      ...       ...        ...              ...             ...
# 5245   0.70900  Jupiter     1.373    Jupiter         0.044210        0.007940
# 5246   6.30000  Jupiter     1.140    Jupiter       115.000000     1176.500000
# 5247   0.70000    Earth     0.913      Earth         0.016340        0.005476
# 5248   1.14000    Earth     1.050      Earth         0.021560        0.008487
# 5249   1.09000    Earth     1.030      Earth         0.028510        0.012868
#
#       eccentricity detection method
# 0             0.23  Radial Velocity
# 1             0.08  Radial Velocity
# 2             0.00  Radial Velocity
# 3             0.37  Radial Velocity
# 4             0.68  Radial Velocity
# ...            ...              ...
# 5245          0.04          Transit
# 5246          0.00   Direct Imaging
# 5247          0.06  Radial Velocity
# 5248          0.00  Radial Velocity
# 5249          0.07  Radial Velocity
#
# [4765 rows x 13 columns]

# %%
# !pip install --user graphviz
# Out:
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: graphviz in /home/15c90f24-b684-480e-97c0-46fdc5052cff/.local/lib/python3.11/site-packages (0.20.3)

# %%
#Decision tree regression
import statsmodels.formula.api as smf
import numpy as np
#import graphviz

from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import export_graphviz

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
nasa_exo_tree = pd.get_dummies(nasa_exo, columns = ["planet type", "mass ssc", "radius ssc", "detection method"], drop_first = True)
nasa_exo_tree
# Out:
#                       name  distance  stellar magnitude  year    mass x  \
# 0     11 Comae Berenices b       304            4.72307  2007  19.40000
# 1       11 Ursae Minoris b       409            5.01300  2009  14.74000
# 2          14 Andromedae b       246            5.23133  2008   4.80000
# 3            14 Herculis b        58            6.61935  2002   8.13881
# 4             16 Cygni B b        69            6.21500  1996   1.78000
# ...                    ...       ...                ...   ...       ...
# 5245                XO-7 b       764           10.52100  2019   0.70900
# 5246              YSES 2 b       357           10.88500  2021   6.30000
# 5247             YZ Ceti b        12           12.07400  2017   0.70000
# 5248             YZ Ceti c        12           12.07400  2017   1.14000
# 5249             YZ Ceti d        12           12.07400  2017   1.09000
#
#       radius x  oribital radius  orbital period  eccentricity  \
# 0        1.080         1.290000        0.892539          0.23
# 1        1.090         1.530000        1.400000          0.08
# 2        1.150         0.830000        0.508693          0.00
# 3        1.120         2.773069        4.800000          0.37
# 4        1.200         1.660000        2.200000          0.68
# ...        ...              ...             ...           ...
# 5245     1.373         0.044210        0.007940          0.04
# 5246     1.140       115.000000     1176.500000          0.00
# 5247     0.913         0.016340        0.005476          0.06
# 5248     1.050         0.021560        0.008487          0.00
# 5249     1.030         0.028510        0.012868          0.07
#
#       planet type_Neptune-like  planet type_Super Earth  \
# 0                        False                    False
# 1                        False                    False
# 2                        False                    False
# 3                        False                    False
# 4                        False                    False
# ...                        ...                      ...
# 5245                     False                    False
# 5246                     False                    False
# 5247                     False                    False
# 5248                     False                     True
# 5249                     False                     True
#
#       planet type_Terrestrial  mass ssc_Jupiter  radius ssc_Jupiter  \
# 0                       False              True                True
# 1                       False              True                True
# 2                       False              True                True
# 3                       False              True                True
# 4                       False              True                True
# ...                       ...               ...                 ...
# 5245                    False              True                True
# 5246                    False              True                True
# 5247                     True             False               False
# 5248                    False             False               False
# 5249                    False             False               False
#
#       detection method_Direct Imaging  detection method_Disk Kinematics  \
# 0                               False                             False
# 1                               False                             False
# 2                               False                             False
# 3                               False                             False
# 4                               False                             False
# ...                               ...                               ...
# 5245                            False                             False
# 5246                             True                             False
# 5247                            False                             False
# 5248                            False                             False
# 5249                            False                             False
#
#       detection method_Eclipse Timing Variations  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 5245                                       False
# 5246                                       False
# 5247                                       False
# 5248                                       False
# 5249                                       False
#
#       detection method_Gravitational Microlensing  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ...                                           ...
# 5245                                        False
# 5246                                        False
# 5247                                        False
# 5248                                        False
# 5249                                        False
#
#       detection method_Orbital Brightness Modulation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# ...                                              ...
# 5245                                           False
# 5246                                           False
# 5247                                           False
# 5248                                           False
# 5249                                           False
#
#       detection method_Pulsar Timing  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
# ...                              ...
# 5245                           False
# 5246                           False
# 5247                           False
# 5248                           False
# 5249                           False
#
#       detection method_Pulsation Timing Variations  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 5245                                         False
# 5246                                         False
# 5247                                         False
# 5248                                         False
# 5249                                         False
#
#       detection method_Radial Velocity  detection method_Transit  \
# 0                                 True                     False
# 1                                 True                     False
# 2                                 True                     False
# 3                                 True                     False
# 4                                 True                     False
# ...                                ...                       ...
# 5245                             False                      True
# 5246                             False                     False
# 5247                              True                     False
# 5248                              True                     False
# 5249                              True                     False
#
#       detection method_Transit Timing Variations
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 5245                                       False
# 5246                                       False
# 5247                                       False
# 5248                                       False
# 5249                                       False
#
# [4765 rows x 24 columns]

# %%
#predicting stellar magnitude, name is irrelevant
x = nasa_exo_tree[["distance", "year", "mass x" , "radius x" , "oribital radius" , "orbital period","eccentricity"]]
x
# Out:
#       distance  year    mass x  radius x  oribital radius  orbital period  \
# 0          304  2007  19.40000     1.080         1.290000        0.892539
# 1          409  2009  14.74000     1.090         1.530000        1.400000
# 2          246  2008   4.80000     1.150         0.830000        0.508693
# 3           58  2002   8.13881     1.120         2.773069        4.800000
# 4           69  1996   1.78000     1.200         1.660000        2.200000
# ...        ...   ...       ...       ...              ...             ...
# 5245       764  2019   0.70900     1.373         0.044210        0.007940
# 5246       357  2021   6.30000     1.140       115.000000     1176.500000
# 5247        12  2017   0.70000     0.913         0.016340        0.005476
# 5248        12  2017   1.14000     1.050         0.021560        0.008487
# 5249        12  2017   1.09000     1.030         0.028510        0.012868
#
#       eccentricity
# 0             0.23
# 1             0.08
# 2             0.00
# 3             0.37
# 4             0.68
# ...            ...
# 5245          0.04
# 5246          0.00
# 5247          0.06
# 5248          0.00
# 5249          0.07
#
# [4765 rows x 7 columns]

# %%
x.dtypes
# Out:
# distance             int64
# year                 int64
# mass x             float64
# radius x           float64
# oribital radius    float64
# orbital period     float64
# eccentricity       float64
# dtype: object

# %%
y = nasa_exo_tree["stellar magnitude"]
y
# Out:
# 0        4.72307
# 1        5.01300
# 2        5.23133
# 3        6.61935
# 4        6.21500
#           ...
# 5245    10.52100
# 5246    10.88500
# 5247    12.07400
# 5248    12.07400
# 5249    12.07400
# Name: stellar magnitude, Length: 4765, dtype: float64

# %%
model = DecisionTreeRegressor(max_depth = 3) #depth = how many layers
model = model.fit(x, y)

# %%
from sklearn.tree import plot_tree
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (10,10), dpi=300)
plot_tree(model)
# Out:
# [Text(0.5, 0.875, 'x[0] <= 543.0\nsquared_error = 9.925\nsamples = 4765\nvalue = 12.693'),
#  Text(0.25, 0.625, 'x[4] <= 0.185\nsquared_error = 9.213\nsamples = 1443\nvalue = 9.378'),
#  Text(0.125, 0.375, 'x[4] <= 0.042\nsquared_error = 8.6\nsamples = 715\nvalue = 11.005'),
#  Text(0.0625, 0.125, 'squared_error = 8.003\nsamples = 225\nvalue = 12.505'),
#  Text(0.1875, 0.125, 'squared_error = 7.367\nsamples = 490\nvalue = 10.316'),
#  Text(0.375, 0.375, 'x[5] <= 590.45\nsquared_error = 4.664\nsamples = 728\nvalue = 7.781'),
#  Text(0.3125, 0.125, 'squared_error = 3.525\nsamples = 698\nvalue = 7.607'),
#  Text(0.4375, 0.125, 'squared_error = 14.207\nsamples = 30\nvalue = 11.812'),
#  Text(0.75, 0.625, 'x[0] <= 1804.5\nsquared_error = 3.389\nsamples = 3322\nvalue = 14.132'),
#  Text(0.625, 0.375, 'x[6] <= 0.005\nsquared_error = 3.791\nsamples = 1320\nvalue = 13.163'),
#  Text(0.5625, 0.125, 'squared_error = 2.822\nsamples = 982\nvalue = 13.524'),
#  Text(0.6875, 0.125, 'squared_error = 5.128\nsamples = 338\nvalue = 12.114'),
#  Text(0.875, 0.375, 'x[0] <= 10471.0\nsquared_error = 2.097\nsamples = 2002\nvalue = 14.772'),
#  Text(0.8125, 0.125, 'squared_error = 1.267\nsamples = 1988\nvalue = 14.713'),
#  Text(0.9375, 0.125, 'squared_error = 50.693\nsamples = 14\nvalue = 23.058')]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
x_train
# Out:
#       distance  year  mass x  radius x  oribital radius  orbital period  \
# 4271      1408  2016    3.46     1.680          0.02980        0.007118
# 2991      3430  2021    2.69     1.446          0.04510        0.009309
# 1355       237  2018    7.27     0.232          0.09460        0.038056
# 4994       310  2020    9.79     0.203          0.06000        0.015332
# 1514       253  2018   14.30     0.244          0.12490        0.053388
# ...        ...   ...     ...       ...              ...             ...
# 3388      4575  2014   15.50     0.362          0.19300        0.082683
# 2285      1767  2016    2.10     1.250          0.03630        0.007940
# 525        343  2021   10.30     0.285          0.11300        0.027926
# 2543      3089  2016    8.75     0.259          0.63140        0.542368
# 888         21  2015    4.74     1.602          0.03876        0.008487
#
#       eccentricity
# 4271          0.00
# 2991          0.00
# 1355          0.00
# 4994          0.04
# 1514          0.04
# ...            ...
# 3388          0.00
# 2285          0.00
# 525           0.20
# 2543          0.00
# 888           0.00
#
# [3812 rows x 7 columns]

# %%
y_test
# Out:
# 2457    15.372
# 103     15.861
# 1809    15.531
# 1530    14.654
# 5215    11.980
#          ...
# 4246    13.644
# 5225    13.855
# 4427    13.488
# 1349    14.175
# 3321    15.822
# Name: stellar magnitude, Length: 953, dtype: float64

# %%
train_tree = DecisionTreeRegressor(max_depth = 3) #depth = how many layers
train_tree = train_tree.fit(x_train, y_train)

# %%
y_test_pred = train_tree.predict(x_test)
#y_test_pred

# %%
mean_squared_error(y_test, y_test_pred)
# Out:
# 4.499754615352656

# %%
y_train_pred = train_tree.predict(x_train)
#y_train_pred

# %%
mean_squared_error(y_train, y_train_pred)
# Out:
# 3.1478482572943705

# %%
#Closest; max depth = 3 is best

# %%
train_tree4 = DecisionTreeRegressor(max_depth = 4) 
train_tree4 = train_tree4.fit(x_train, y_train)
y_test_pred4 = train_tree4.predict(x_test)
mean_squared_error(y_test, y_test_pred4)
# Out:
# 4.150229849765269

# %%
y_train_pred4 = train_tree4.predict(x_train)
mean_squared_error(y_train, y_train_pred4)
# Out:
# 2.807245661302309

# %%
train_tree5 = DecisionTreeRegressor(max_depth = 5) 
train_tree5 = train_tree5.fit(x_train, y_train)
y_test_pred5 = train_tree5.predict(x_test)
mean_squared_error(y_test, y_test_pred5)
# Out:
# 3.9794156016031232

# %%
y_train_pred5 = train_tree5.predict(x_train)
mean_squared_error(y_train, y_train_pred5)
# Out:
# 2.415203055145155

# %%
#Linear Regression

# %%
lm_nasa_exo = LinearRegression()
lm_nasa_exo.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model_pred = lm_nasa_exo.predict(x_test)
mean_squared_error(y_test,model_pred)
# Out:
# 5.266750946144663

# %%
train_tree10 = DecisionTreeRegressor(max_depth = 10) 
train_tree10 = train_tree10.fit(x_train, y_train)
y_test_pred10 = train_tree10.predict(x_test)
y_train_pred10 = train_tree10.predict(x_train)
mean_squared_error(y_test, y_test_pred10)
# Out:
# 4.090709339383572

# %%
mean_squared_error(y_train, y_train_pred10)
# Out:
# 1.0935054210605506

# %%
#Milestone 3
